# %% [markdown]
# ## 3D pipelines reconstruction project - Conception Détaillé

# %% [markdown]
# #### ------------------------------------------------------------------TODO---------------------------------------------------------------------------------------------
# * Compléter les entêtes des fonctions (headers)
# * Compléter les classes
# * Compléter les diagrammes de classe et autres diagrammes
# * Vérifier la cohérence entrées/sorties -> Test
# * Construire l'environnement sur pycharm (Dockerizer ?)
# * Construire le projet, les fichier, leurs hiérarchie, le main et makefile
# *
# * recherche de fonctionnalités existantes, de code et integrer les headers -> test
# * tests unitaires sur les fonctionnalités
# *
# * Compléter document
# #### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Étape 1 : Classification des points

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-02.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-02.png)

# %% [markdown]
# #### Labellisation du type d’élément

# %% [markdown]
# Un premier réseau retourne pour chaque point un label correspondant à un type d’élément de pipeline ou “extérieur” si le point n’en fait pas partie.

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Filtrage des points n’appartenant pas au pipeline

# %% [markdown]
# Les points détectés comme extérieurs au pipeline sont ignorés

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Détermination du rayon et de la direction

# %% [markdown]
# Un deuxième réseau de neurones avec utilisation du Multi-task learning afin de déterminer, pour chaque point, le rayon et la direction de l’élément qui lui est associé

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Classification d'un point

# %% [markdown]
# La solution doit être capable de prendre en entrée un nuage de points 3D non traités (uniquement les coordonnées sont disponibles), et de retourner un ensemble de points suspectés d’appartenir au pipeline étudié. Pour chaque point le réseau détermine :
# * L’élément de pipeline auquel il est suspecté d’appartenir
# * Le rayon de cet élément
# * La direction de cet élément

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result
