# %% [markdown]
# ## 3D pipelines reconstruction project - Conception Détaillé

# %% [markdown]
# #### ------------------------------------------------------------------TODO---------------------------------------------------------------------------------------------
# * Compléter les entêtes des fonctions (headers)
# * Compléter les classes
# * Compléter les diagrammes de classe et autres diagrammes
# * Vérifier la cohérence entrées/sorties -> Test
# * Construire l'environnement sur pycharm (Dockerizer ?)
# * Construire le projet, les fichier, leurs hiérarchie, le main et makefile
# *
# * recherche de fonctionnalités existantes, de code et integrer les headers -> test
# * tests unitaires sur les fonctionnalités
# *
# * Compléter document
# #### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Rappel du pipeline

# %% [markdown]
# ![DeepPipes-001.png](attachment:DeepPipes-001.png)

# %% [markdown]
# ##### * Étape 0 : Génération des modèles d’entraînement
# #####   *   Étape 0-bis : Entraînement des réseaux
# ##### * Étape 1 : Classification des points
# #####   * Étape 2 : Création de l'arbre
# #####   * Étape 3 : Reconstruction du modèle 3D
# #####   * Étape 4 : Affinement des résultats
# #####   * Étape 5 : Exportation du modèle

# %% [markdown]
# ![](https://lucid.app/documents/edit/aa97f985-7d79-4c1f-8e19-a6d903060b26/0?callback=close&name=docs&callback_type=back&v=498&s=593)

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))

# %% [markdown]
# %%html
# <iframe src="https://lucid.app/documents/edit/aa97f985-7d79-4c1f-8e19-a6d903060b26/0?callback=close&name=docs&callback_type=back&v=498&s=593)" width="1200" height="1000"></iframe>

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-17-51.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-17-51.png)

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Librairies et outils utilisés

# %% [markdown]
# https://github.com/yangyanli/PointCNN

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csgraph.minimum_spanning_tree.html

# %% [markdown]
# https://github.com/ClayFlannigan/icp

# %% [markdown]
# https://numpy.org/

# %% [markdown]
# https://pytorch.org/

# %% [markdown]
# https://networkx.org/

# %% [markdown]
# http://www.open3d.org/

# %%
import numpy as np
import open3d as o3

# %% [markdown]
# ### Éléments 3D

# %%
print("Let's draw a textured triangle mesh from obj file.")
textured_mesh = o3d.io.read_triangle_mesh("Modular_Pipes_3D Model.obj")
textured_mesh.compute_vertex_normals()
#o3d.visualization.draw_geometries([textured_mesh])
# Out:
# Let's draw a textured triangle mesh from obj file.
# [Open3D WARNING] Unable to load file Modular_Pipes_3D Model.obj with ASSIMP
# TriangleMesh with 0 points and 0 triangles.

# %%
class MyClass:
    """Un example simple de classe"""
    i = 12345

    def __init__(self):
        self.data = []
    def add(self, x):
        self.data.append(x)
    def addtwice(self, x):
        self.add(x)
        self.add(x)

# %% [markdown]
# #### Éléments simples (Tuyaux, Flasques et Coudes)

# %% [markdown]
# https://www.cgtrader.com/free-3d-models/various/various-models/modular-pipes-3d-model

# %% [markdown]
# FORMATS :
# #### * .obj,
# * .max,
# * .fbx

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-22.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-22.png)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-33.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-33.png)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-52.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-23-52.png)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-24-02.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-24-02.png)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-22-21.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-22-21.png)

# %% [markdown]
# #### Éléments plus complexes (Tés et Croix)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-31-45.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-31-45.png)

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-22-32.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2011-22-32.png)

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Générateur de modèle 3D

# %% [markdown]
# Reconstruit un modèle 3D à partir d'un graphe de points (part type, radius, orientation, position)

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## I - Reconstruction sur le schèma de DeepPipe

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-02.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-02.png)

# %% [markdown]
# ### Pipeline complète de base

# %% [markdown]
# L’utilisateur est capable de démarrer la chaîne de traitement DeepPipes à l’aide d’un unique point d’entrée, en utilisant comme input un nuage de points 3D correspondant à un réseau de pipeline.

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# ## II - Intégration de PCEDNET

# %% [markdown]
# #### Étape 1-bis : Classification des points avec PCEDNET

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# ### Pipeline complète avec PCEDNET

# %% [markdown]
# En remplaçant l’étape de classification de DeepPipes par un équivalent effectué à l’aide de PCEDNet

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# ## III - Comparaison des résultats

# %% [markdown]
# #### Mesures d’efficacité

# %% [markdown]
# Comparer les mesures de similitudes de chaque méthode sur les mêmes données initiales

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Mesures de performances

# %% [markdown]
# Comparer les temps d’apprentissage et d’exécution des deux méthodes

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Comparaison des résultats

# %% [markdown]
# La solution propose une étude comparative entre DeepPipe et la solution décrite en CO-009

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result
