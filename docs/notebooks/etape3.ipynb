# %% [markdown]
# ## 3D pipelines reconstruction project - Conception Détaillé

# %% [markdown]
# #### ------------------------------------------------------------------TODO---------------------------------------------------------------------------------------------
# * Compléter les entêtes des fonctions (headers)
# * Compléter les classes
# * Compléter les diagrammes de classe et autres diagrammes
# * Vérifier la cohérence entrées/sorties -> Test
# * Construire l'environnement sur pycharm (Dockerizer ?)
# * Construire le projet, les fichier, leurs hiérarchie, le main et makefile
# *
# * recherche de fonctionnalités existantes, de code et integrer les headers -> test
# * tests unitaires sur les fonctionnalités
# *
# * Compléter document
# #### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Étape 3 : Reconstruction du modèle 3D

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-20.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-20.png)

# %% [markdown]
# #### Création d’un dictionnaire de modèles 3D pour les éléments

# %% [markdown]
# Créer un dictionnaire associant chaque type d’élément de pipeline à un modèle 3D

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Placement des modèles dans l’espace

# %% [markdown]
# Pour chaque élément du graphe de pipeline, le modèle 3D associé est sélectionné, puis placé et orienté dans l’espace

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Mise à l’échelle des composants

# %% [markdown]
# Chaque composant est mis à l’échelle afin de correspondre au rayon de l’élément de graphe correspondant

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result
