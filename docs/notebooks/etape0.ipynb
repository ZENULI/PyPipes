# %% [markdown]
# ## 3D pipelines reconstruction project - Conception Détaillé

# %% [markdown]
# #### ------------------------------------------------------------------TODO---------------------------------------------------------------------------------------------
# * Compléter les entêtes des fonctions (headers)
# * Compléter les classes
# * Compléter les diagrammes de classe et autres diagrammes
# * Vérifier la cohérence entrées/sorties -> Test
# * Construire l'environnement sur pycharm (Dockerizer ?)
# * Construire le projet, les fichier, leurs hiérarchie, le main et makefile
# *
# * recherche de fonctionnalités existantes, de code et integrer les headers -> test
# * tests unitaires sur les fonctionnalités
# *
# * Compléter document
# #### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Étape 0 : Génération des modèles d’entraînement

# %% [markdown]
# #### Génération d’un pipeline aléatoire

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-13.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-13.png)

# %% [markdown]
#  produire un graphe représentant un réseau de tuyauterie aléatoire et cohérent avec les règles présentées

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Transformation en nuages de points

# %% [markdown]
# Le graphe généré doit pouvoir être transformé en nuage de points (Nombre de points paramétrables)

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Ajout de bruit

# %% [markdown]
# Il est possible de bruiter le nuage de points obtenu de façon paramétrable

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### Générer une base de donnnées d'entrainement

# %% [markdown]
# Minimal : La solution est capable de générer un réseau composé de tuyaux, flasques et coudes cohérent, et de le transformer en un nuage de points, chaque point étant caractérisé par sa position {x, y, z}, son type, son rayon et sa direction
#
# Maximal : Les réseaux générés peuvent également utiliser des éléments de type tés et croix. Le nuage de points résultant peut être bruité
#
# Les réseaux sont générés sous deux formes :
# * Référence : Un graphe pondéré où chaque nœud correspond à un élément de pipeline, caractérisé par son type, ses coordonnées, son rayon et sa direction. Chaque arête est pondérée par la distance Euclidienne entre deux éléments
# * Nuage de point : Un nuage de points calculé à partir de sa représentation 3D

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Étape 0-bis : Entraînement des réseaux

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-08.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20de%202022-01-04%2009-18-08.png)

# %%
def fonction(param): 
    """
    Return the ... 
    
    In  : 
    out : 
    """
    result = 0

    return result
